# %% [markdown]
# # 2025 Model Run
# This notebook applies the trained models to the 2025 Tour de France startlist to generate Top 20, Top 10, and Top 5 finish predictions.
#
# ## Key Steps:
# - Loads the 2025 startlist and feature data
# - Applies trained models to calculate probabilities and predictions
# - Merges results with rider names and exports final predictions to CSV

# %% [markdown]
# ## Import Libraries

# %%
from pathlib import Path
import sys
import joblib
import pandas as pd
import unidecode

# %% [markdown]
# ## Set Folder Path and Read CSVs

# %%
def find_project_root(start: Path, anchor_dirs=("src", "Data")) -> Path:
    """
    Walk up the directory tree until we find a folder that
    contains all anchor_dirs (e.g. 'src' and 'Data').
    """
    path = start.resolve()
    for parent in [path] + list(path.parents):
        if all((parent / d).is_dir() for d in anchor_dirs):
            return parent
    raise FileNotFoundError("Could not locate project root")

# %%
# Locate the project root regardless of notebook depth
project_root = find_project_root(Path.cwd())

# ----- Code modules --------------------------------------------------
src_path = project_root / "src"
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

from data_prep import preprocess_tdf_data   # import data preproc function

# ----- Data ----------------------------------------------------------
data_path = project_root / "Data" / "Processed"
raw_path = project_root / "Data" / "Raw"
print("Raw data folder:", data_path)
# Out:
# Raw data folder: C:\Users\Shaun Ricketts\Documents\Projects\Cycling\Tour de France Predictor - 2025\Data\Processed\2025

# %%
# Race data
df = pd.read_csv(data_path / "tdf_prepared.csv")

# %%
# 2025 TDF Startlist
startlist = pd.read_csv(raw_path / "TDF_Startlist_2025.csv")

# %%
# Rankings of riders per year by First Cycling's points system, then split the df to get Rider names in a seperate df
fc_rank = pd.read_csv(raw_path / "fc_rankings.csv", usecols=["rider_id","Rider"])
rider_names = fc_rank.drop_duplicates(subset='rider_id', keep="first")

# %%
# import missing_value_handler
from missing_value_handler import FillWithSentinel

# %%
cleaner = FillWithSentinel()
df = cleaner.fit_transform(df)

# %%
df = df[df['Year'] == 2025]

# %%
startlist['Rider_ID'] = startlist['url'].str.extract(r"r=(\d+)", expand=False).astype(int)

# %%
# Filter test so it only has riders who are starting the Tour de France
df = df[df['Rider_ID'].isin(startlist['Rider_ID'])]

# %%
features_top20 = ['Best_Pos_BT_UWT', 'Best_Pos_BT_PT',
            'FC_Pos_YB', 'best_recent_tdf_result',
            'best_recent_other_gt_result', 'rode_giro']

# %%
features_top5 = ['Best_Pos_BT_UWT', 'Best_Pos_BT_PT',
            'FC_Pos_YB', 'best_recent_tdf_result',
            'best_recent_other_gt_result']

# %%
test_top20 = df[features_top20]

# %%
test_top10 = df[features_top5]

# %%
test_top5 = df[features_top5]

# %% [markdown]
# # Run The Models

# %%
model_dir = project_root / "Models"
model_dir.mkdir(parents=True, exist_ok=True)

# %%
# Load best models from GridSearchCV (already trained and saved)
model_top20 = joblib.load(model_dir / "final_model_top20.pkl")
model_top10 = joblib.load(model_dir / "final_model_top10.pkl")
model_top5 = joblib.load(model_dir / "final_model_top5.pkl")

# %%
# Probabilities for class 1 (top 20 finish)
probs_top20 = model_top20.predict_proba(test_top20)[:, 1]
probs_top10 = model_top10.predict_proba(test_top10)[:, 1]
probs_top5 = model_top5.predict_proba(test_top5)[:, 1]

# Class predictions (0 or 1):
preds_top20 = model_top20.predict(test_top20)
preds_top10 = model_top10.predict(test_top10)
preds_top5 = model_top5.predict(test_top5)

# %%
df['top20_probability'] = probs_top20
df['top20_prediction'] = preds_top20

df['top10_probability'] = probs_top10
df['top10_prediction'] = preds_top10

df['top5_probability'] = probs_top5
df['top5_prediction'] = preds_top5

# %%
# Make sure the ID columns match in name
# Rename 'rider_id' in rider_names to match 'Rider_ID' in df
rider_names = rider_names.rename(columns={'rider_id': 'Rider_ID'})

# Merge on Rider_ID
df = df.merge(rider_names, on='Rider_ID', how='left')

# %%
df = df[["Rider_ID"] + ["Rider"] + ["top20_probability"] +  ["top10_probability"] + ['top5_probability'] + features_top20]

# %%
def clean_and_reorder(name):
    # Split by double space to separate surname and first name
    parts = name.split("  ")
    # Reverse order: first name + last name
    reordered = " ".join(parts[::-1])
    # Remove special characters
    cleaned = unidecode.unidecode(reordered)
    return cleaned

# %%
# Reorder names and remove special characters
df["Rider"] = df["Rider"].apply(clean_and_reorder)

# %%
df.sort_values(by='top20_probability', ascending=False).reset_index(drop=True).head(20)
# Out:
#     Rider_ID                     Rider  top20_probability  top10_probability  \
# 0      45992             Tadej Pogacar           0.837129           0.790385
# 1      84019           Remco Evenepoel           0.822488           0.746009
# 2      38195          Jonas Vingegaard           0.808906           0.784846
# 3       1527                 Enric Mas           0.762726           0.554411
# 4      84926          Carlos Rodriguez           0.748783           0.667273
# 5      50303              Joao Almeida           0.742168           0.537586
# 6      68206          Matteo Jorgenson           0.737900           0.543332
# 7      42186              Ben O'Connor           0.717500           0.457225
# 8      81835         Santiago Buitrago           0.571216           0.097603
# 9      37281          Aleksandr Vlasov           0.546545           0.362666
# 10     18655             Primoz Roglic           0.545751           0.460801
# 11      6242               Simon Yates           0.540799           0.302596
# 12     20147                Adam Yates           0.538491           0.408806
# 13     10990          Guillaume Martin           0.520290           0.094896
# 14     76474           Ilan Van Wilder           0.490837           0.088938
# 15     77103  Mattias Skjelmose Jensen           0.470446           0.274100
# 16     48008                 Sepp Kuss           0.469163           0.129072
# 17     48547                Felix Gall           0.463489           0.162374
# 18      9344          Emanuel Buchmann           0.453333           0.046418
# 19    130790          Florian Lipowitz           0.390310           0.145677
#
#     top5_probability Best_Pos_BT_UWT Best_Pos_BT_PT  FC_Pos_YB  \
# 0           0.780886             1.0            999          1
# 1           0.200891             4.0            999          2
# 2           0.771078             2.0            1.0          6
# 3           0.446888             2.0           18.0         11
# 4           0.052539             6.0            6.0         13
# 5           0.317106             1.0            2.0         30
# 6           0.259159             1.0            999         14
# 7           0.233038             7.0           10.0          5
# 8           0.011811            13.0            1.0         56
# 9           0.026463            21.0           17.0         15
# 10          0.467931             1.0            8.0          7
# 11          0.058430             1.0            999         75
# 12          0.033159            12.0            1.0         18
# 13          0.012249            10.0            999         48
# 14          0.013710             6.0            7.0         72
# 15          0.046826             5.0            999         22
# 16          0.048264            13.0           38.0        105
# 17          0.014849             4.0            5.0         82
# 18          0.009731            11.0           31.0        284
# 19          0.037152             2.0            999         66
#
#     best_recent_tdf_result  best_recent_other_gt_result  rode_giro
# 0                      1.0                          1.0        0.0
# 1                      3.0                          1.0        0.0
# 2                      1.0                          2.0        0.0
# 3                     19.0                          2.0        0.0
# 4                      5.0                          7.0        0.0
# 5                      4.0                          3.0        0.0
# 6                      8.0                        999.0        0.0
# 7                     17.0                          2.0        0.0
# 8                     10.0                         10.0        0.0
# 9                      5.0                          7.0        0.0
# 10                   999.0                          1.0        1.0
# 11                     4.0                        999.0        1.0
# 12                     3.0                         12.0        1.0
# 13                    10.0                         14.0        0.0
# 14                    26.0                         12.0        0.0
# 15                    29.0                          5.0        0.0
# 16                    12.0                          1.0        0.0
# 17                     8.0                         29.0        0.0
# 18                    21.0                          7.0        0.0
# 19                   999.0                          7.0        0.0

# %%
df.sort_values(by='top10_probability', ascending=False).reset_index(drop=True).head(20)
# Out:
#     Rider_ID                     Rider  top20_probability  top10_probability  \
# 0      45992             Tadej Pogacar           0.837129           0.790385
# 1      38195          Jonas Vingegaard           0.808906           0.784846
# 2      84019           Remco Evenepoel           0.822488           0.746009
# 3      84926          Carlos Rodriguez           0.748783           0.667273
# 4       1527                 Enric Mas           0.762726           0.554411
# 5      68206          Matteo Jorgenson           0.737900           0.543332
# 6      50303              Joao Almeida           0.742168           0.537586
# 7      18655             Primoz Roglic           0.545751           0.460801
# 8      42186              Ben O'Connor           0.717500           0.457225
# 9      20147                Adam Yates           0.538491           0.408806
# 10     37281          Aleksandr Vlasov           0.546545           0.362666
# 11      6242               Simon Yates           0.540799           0.302596
# 12     77103  Mattias Skjelmose Jensen           0.470446           0.274100
# 13       716            Geraint Thomas           0.368214           0.189346
# 14     48547                Felix Gall           0.463489           0.162374
# 15    130790          Florian Lipowitz           0.390310           0.145677
# 16     78129           Thymen Arensman           0.258551           0.144007
# 17     48008                 Sepp Kuss           0.469163           0.129072
# 18     81835         Santiago Buitrago           0.571216           0.097603
# 19     10990          Guillaume Martin           0.520290           0.094896
#
#     top5_probability Best_Pos_BT_UWT Best_Pos_BT_PT  FC_Pos_YB  \
# 0           0.780886             1.0            999          1
# 1           0.771078             2.0            1.0          6
# 2           0.200891             4.0            999          2
# 3           0.052539             6.0            6.0         13
# 4           0.446888             2.0           18.0         11
# 5           0.259159             1.0            999         14
# 6           0.317106             1.0            2.0         30
# 7           0.467931             1.0            8.0          7
# 8           0.233038             7.0           10.0          5
# 9           0.033159            12.0            1.0         18
# 10          0.026463            21.0           17.0         15
# 11          0.058430             1.0            999         75
# 12          0.046826             5.0            999         22
# 13          0.042168            28.0           95.0        100
# 14          0.014849             4.0            5.0         82
# 15          0.037152             2.0            999         66
# 16          0.015271             3.0            2.0         76
# 17          0.048264            13.0           38.0        105
# 18          0.011811            13.0            1.0         56
# 19          0.012249            10.0            999         48
#
#     best_recent_tdf_result  best_recent_other_gt_result  rode_giro
# 0                      1.0                          1.0        0.0
# 1                      1.0                          2.0        0.0
# 2                      3.0                          1.0        0.0
# 3                      5.0                          7.0        0.0
# 4                     19.0                          2.0        0.0
# 5                      8.0                        999.0        0.0
# 6                      4.0                          3.0        0.0
# 7                    999.0                          1.0        1.0
# 8                     17.0                          2.0        0.0
# 9                      3.0                         12.0        1.0
# 10                     5.0                          7.0        0.0
# 11                     4.0                        999.0        1.0
# 12                    29.0                          5.0        0.0
# 13                     3.0                          2.0        0.0
# 14                     8.0                         29.0        0.0
# 15                   999.0                          7.0        0.0
# 16                   999.0                          6.0        1.0
# 17                    12.0                          1.0        0.0
# 18                    10.0                         10.0        0.0
# 19                    10.0                         14.0        0.0

# %%
df.sort_values(by='top5_probability', ascending=False).reset_index(drop=True).head(10)
# Out:
#    Rider_ID              Rider  top20_probability  top10_probability  \
# 0     45992      Tadej Pogacar           0.837129           0.790385
# 1     38195   Jonas Vingegaard           0.808906           0.784846
# 2     18655      Primoz Roglic           0.545751           0.460801
# 3      1527          Enric Mas           0.762726           0.554411
# 4     50303       Joao Almeida           0.742168           0.537586
# 5     68206   Matteo Jorgenson           0.737900           0.543332
# 6     42186       Ben O'Connor           0.717500           0.457225
# 7     84019    Remco Evenepoel           0.822488           0.746009
# 8     41249  Jhonnatan Narvaez           0.267659           0.087959
# 9    159196     Lenny Martinez           0.286946           0.082541
#
#    top5_probability Best_Pos_BT_UWT Best_Pos_BT_PT  FC_Pos_YB  \
# 0          0.780886             1.0            999          1
# 1          0.771078             2.0            1.0          6
# 2          0.467931             1.0            8.0          7
# 3          0.446888             2.0           18.0         11
# 4          0.317106             1.0            2.0         30
# 5          0.259159             1.0            999         14
# 6          0.233038             7.0           10.0          5
# 7          0.200891             4.0            999          2
# 8          0.069258             1.0            999         51
# 9          0.066780             2.0           11.0         35
#
#    best_recent_tdf_result  best_recent_other_gt_result  rode_giro
# 0                     1.0                          1.0        0.0
# 1                     1.0                          2.0        0.0
# 2                   999.0                          1.0        1.0
# 3                    19.0                          2.0        0.0
# 4                     4.0                          3.0        0.0
# 5                     8.0                        999.0        0.0
# 6                    17.0                          2.0        0.0
# 7                     3.0                          1.0        0.0
# 8                   999.0                         28.0        0.0
# 9                   124.0                         24.0        0.0

# %%
df.to_csv(data_path / "TDF_2025_Predictions.csv", index=False)
