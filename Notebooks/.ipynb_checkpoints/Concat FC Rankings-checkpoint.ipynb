# %%
import pandas as pd

# %%
folder_path = r"D:\Data\Cycling"

# %%
fc_02_11 = pd.read_csv(folder_path+"/fc_rankings_2002_2011.csv")
fc_12_22 = pd.read_csv(folder_path+"/fc_rankings_2012_2022.csv")
fc_23_24 = pd.read_csv(folder_path+"/fc_rankings_2023_2024.csv")

# %%
fc_rankings_2002_2024 = pd.concat([fc_02_11, fc_12_22, fc_23_24], ignore_index=True)

# %%
fc_rankings_2002_2024
# Out:
#        index   Pos                   Rider  Born     Nation  \
# 0          1     1             Zabel  Erik  1970    Germany
# 1          2     2          McEwen  Robbie  1972  Australia
# 2          3     3        Armstrong  Lance  1971        USA
# 3          4     4          Bettini  Paolo  1974      Italy
# 4          5     5   Casagrande  Francesco  1970      Italy
# ...      ...   ...                     ...   ...        ...
# 91714   7170  3247           Wang  Mengjie  2001      China
# 91715   7171  3247          Torres  Melvin  2005  Guatemala
# 91716   7172  3247           Wan  Ta Chung  2005     Taiwan
# 91717   7173  3247  Fotsing  Claude Harold  2003   Cameroon
# 91718   7174  3247             Yu  Jiaqing  2004      China
#
#                                 Team  Points  rider_id  Year
# 0                       Team Telekom    3063       236  2002
# 1                     Lotto - Adecco    2736       173  2002
# ...

# %%
fc_rankings_2002_2024.to_csv("D:/Data/Cycling/TDF_Predictor/fc_rankings_2002_2024.csv", index=False)
